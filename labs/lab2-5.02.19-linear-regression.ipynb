# %%
import numpy as np
import matplotlib.pyplot as plt

plt.grid()
np.set_printoptions(precision=2)

# %%
x = np.arange( -2, 2, .5)

# %%
x1 = np.linspace(-2, 2, 9)

# %%
plt.plot(x)

plt.show()

# %%
rand = np.random.rand

# %%
def rand(count, max_val=10):
    return np.random.rand(count) * max_val

# %%
y1 = (2*x1) + 1

# %%
plt.plot(x1,y1)
plt.show()

# %%
x = np.linspace(-3,3,50)
x
# Out:
# array([-3.  , -2.88, -2.76, -2.63, -2.51, -2.39, -2.27, -2.14, -2.02,
#        -1.9 , -1.78, -1.65, -1.53, -1.41, -1.29, -1.16, -1.04, -0.92,
#        -0.8 , -0.67, -0.55, -0.43, -0.31, -0.18, -0.06,  0.06,  0.18,
#         0.31,  0.43,  0.55,  0.67,  0.8 ,  0.92,  1.04,  1.16,  1.29,
#         1.41,  1.53,  1.65,  1.78,  1.9 ,  2.02,  2.14,  2.27,  2.39,
#         2.51,  2.63,  2.76,  2.88,  3.  ])

# %%
y = (2 * (x **3)) + (4*x) + 1

y
# Out:
# array([-65.  , -58.16, -51.85, -46.02, -40.68, -35.78, -31.31, -27.25,
#        -23.58, -20.27, -17.3 , -14.65, -12.29, -10.22,  -8.39,  -6.8 ,
#         -5.42,  -4.22,  -3.19,  -2.3 ,  -1.54,  -0.87,  -0.28,   0.25,
#          0.75,   1.25,   1.75,   2.28,   2.87,   3.54,   4.3 ,   5.19,
#          6.22,   7.42,   8.8 ,  10.39,  12.22,  14.29,  16.65,  19.3 ,
#         22.27,  25.58,  29.25,  33.31,  37.78,  42.68,  48.02,  53.85,
#         60.16,  67.  ])

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %%
x = np.arange(-3,3,.1)
y = np.cos(x)

x,y
# Out:
# (array([-3.00e+00, -2.90e+00, -2.80e+00, -2.70e+00, -2.60e+00, -2.50e+00,
#         -2.40e+00, -2.30e+00, -2.20e+00, -2.10e+00, -2.00e+00, -1.90e+00,
#         -1.80e+00, -1.70e+00, -1.60e+00, -1.50e+00, -1.40e+00, -1.30e+00,
#         -1.20e+00, -1.10e+00, -1.00e+00, -9.00e-01, -8.00e-01, -7.00e-01,
#         -6.00e-01, -5.00e-01, -4.00e-01, -3.00e-01, -2.00e-01, -1.00e-01,
#          2.66e-15,  1.00e-01,  2.00e-01,  3.00e-01,  4.00e-01,  5.00e-01,
#          6.00e-01,  7.00e-01,  8.00e-01,  9.00e-01,  1.00e+00,  1.10e+00,
#          1.20e+00,  1.30e+00,  1.40e+00,  1.50e+00,  1.60e+00,  1.70e+00,
#          1.80e+00,  1.90e+00,  2.00e+00,  2.10e+00,  2.20e+00,  2.30e+00,
#          2.40e+00,  2.50e+00,  2.60e+00,  2.70e+00,  2.80e+00,  2.90e+00]),
#  array([-0.99, -0.97, -0.94, -0.9 , -0.86, -0.8 , -0.74, -0.67, -0.59,
#         -0.5 , -0.42, -0.32, -0.23, -0.13, -0.03,  0.07,  0.17,  0.27,
#          0.36,  0.45,  0.54,  0.62,  0.7 ,  0.76,  0.83,  0.88,  0.92,
# ...

# %%
plt.plot(x,y)
plt.grid()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
def plot(x,y):
    plt.plot(x,y)
    plt.grid()
    plt.xlabel('x-axis')
    plt.ylabel('y-axis')
    plt.show()
    
plot(x,y)

# %%
x = np.arange(-10,10,.01)
y = np.sin(x)

plot(x,y)

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.show()

# %%
# %%markdown
#
# ## EX: lab-3 : Simple Linear Regression
# Out:
# ## EX: lab-3 : Simple Linear Regression

# %%
a = np.array([166,195,200,260,265,335,370,450,517,552])
b = np.array([54,82,72,72,90,124,94,118,152,132])

a
# Out:
# array([166, 195, 200, 260, 265, 335, 370, 450, 517, 552])

# %%
b
# Out:
# array([ 54,  82,  72,  72,  90, 124,  94, 118, 152, 132])

# %%
m = rand(10)
n = rand(10)

print('m: ')
print(m)
print('n: ')
print(m)

np.multiply(m,n)
# Out:
# m:
# [7.54 3.25 8.53 9.71 1.5  9.32 8.18 3.94 7.93 8.55]
# n:
# [7.54 3.25 8.53 9.71 1.5  9.32 8.18 3.94 7.93 8.55]
# array([11.7 ,  1.28,  5.25,  9.63,  6.76, 76.62, 48.41, 18.27, 40.41,
#        79.35])

# %%
plt.plot(a,b,'o')

# %%
n = a.size
n
# Out:
# 10

# %%
c1 = 0
c2 = 0

a.sum()
# Out:
# 3310

# %%
b.sum()
# Out:
# 990

# %%
a*b
# Out:
# array([ 8964, 15990, 14400, 18720, 23850, 41540, 34780, 53100, 78584,
#        72864])

# %%
a.dot(b)
# Out:
# 362792

# %%
np.multiply(a,b)
# Out:
# array([ 8964, 15990, 14400, 18720, 23850, 41540, 34780, 53100, 78584,
#        72864])

# %%
top = (n * np.sum(a.dot(b))) - (a.sum() * b.sum())
top
# Out:
# array([-2713845.62, -3134062.13, -3053584.05, -2916888.66, -1637166.81,
#         -294366.42, -1130174.28, -1595878.44, -1428902.72,    90990.28])

# %%
bottom = ( (n * np.sum(a.dot(a))) - (np.sum(a))**2 )
bottom
# Out:
# array([ -8989674.56, -10457249.41, -10176185.7 ,  -9698787.26,
#         -5229454.15,   -539823.93,  -3458820.53,  -5085257.58,
#         -4502107.33,    806005.6 ])

# %%
z1 = top / bottom

z1
# Out:
# array([0.3 , 0.3 , 0.3 , 0.3 , 0.31, 0.55, 0.33, 0.31, 0.32, 0.11])

# %%
((n * np.sum(a.dot(b))) - (a.sum() * b.sum()) / ( (n * np.sum(a.dot(a))) - (np.sum(a))**2 ))
# Out:
# array([ 563054.75,  142838.18,  223316.27,  360011.68, 1639733.81,
#        2982539.65, 2146726.67, 1681022.21, 1847998.01, 3367886.22])

# %%
'a: ' + str(a)
# Out:
# 'a: [166 195 200 260 265 335 370 450 517 552]'

# %%
'b: ' + str(b)
# Out:
# 'b: [ 54  82  72  72  90 124  94 118 152 132]'

# %%
a1 = (n * np.sum(a.dot(b)) - (a.sum() * b.sum())) / (n * np.sum(a.dot(a)) - (a.sum())**2 )
a1
# Out:
# array([0.3 , 0.3 , 0.3 , 0.3 , 0.31, 0.55, 0.33, 0.31, 0.32, 0.11])

# %%
a**2
# Out:
# array([ 27556,  38025,  40000,  67600,  70225, 112225, 136900, 202500,
#        267289, 304704], dtype=int32)

# %%
b1 = (np.sum(a**2) * b.sum()) - ( np.sum(a*b) * a.sum() ) / ((n * np.sum(a**2)) - (a.sum())**2 )
b1
# Out:
# array([1.25e+09, 1.25e+09, 1.25e+09, 1.25e+09, 1.25e+09, 1.25e+09,
#        1.25e+09, 1.25e+09, 1.25e+09, 1.25e+09])

# %%
y = c1*a + c2
# Out:
# array([1.25e+09, 1.25e+09, 1.25e+09, 1.25e+09, 1.25e+09, 1.25e+09,
#        1.25e+09, 1.25e+09, 1.25e+09, 1.25e+09])

# %%
plt.plot(a,b,'o')

plt.show()
